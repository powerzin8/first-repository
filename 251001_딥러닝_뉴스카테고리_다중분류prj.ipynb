# %% [markdown]
# <a href="https://colab.research.google.com/github/powerzin8/first-repository/blob/master/251001_%EB%94%A5%EB%9F%AC%EB%8B%9D_%EB%89%B4%EC%8A%A4%EC%B9%B4%ED%85%8C%EA%B3%A0%EB%A6%AC_%EB%8B%A4%EC%A4%91%EB%B6%84%EB%A5%98prj.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #오늘 할일
# ### 실험 또 실험 🤯
#
#
# 1. 단어장 개수를 바꾸면서(10000, 5000, Nan) 8개의 ML모델을 사용해보고  accuacry와 f1-score를 비교
# (표로 나타내보세요~) (벡터화는 tf-idf로 통일)
#
#
# ### 📊 단어장 개수별 ML 모델 성능 비교 (Accuracy / F1-score)
#
# | Vocabulary Size | Model             | Accuracy | F1-Score |
# |------------------|------------------|----------|----------|
# | 10000            | LogisticRegression | 0.7956 | 0.4721 |
# |                  | SVM                | 0.8299 | 0.6808 |
# |                  | RandomForest       | 0.7542 | 0.4341 |
# |                  | XGBoost            | 0.7925 | 0.6387 |
# |                  | NaiveBayes         | 0.7707 | 0.4784 |
# |                  | KNN                | 0.7894 | 0.5903 |
# |                  | LightGBM           | 0.2524 | 0.0144 |
# |                  | DecisionTree       | 0.6968 | 0.4603 |
# | 5000             | LogisticRegression | 0.7979 | 0.4814 |
# |                  | SVM                | 0.8290 | 0.6814 |
# |                  | RandomForest       | 0.7685 | 0.4463 |
# |                  | XGBoost            | 0.7996 | 0.6540 |
# |                  | NaiveBayes         | 0.7707 | 0.4820 |
# |                  | KNN                | 0.7823 | 0.5819 |
# |                  | LightGBM           | 0.3491 | 0.0113 |
# |                  | DecisionTree       | 0.6995 | 0.4480 |
# | NaN (All words)  | LogisticRegression | 0.7916 | 0.4514 |
# |                  | SVM                | 0.8295 | 0.6887 |
# |                  | RandomForest       | 0.7418 | 0.4135 |
# |                  | XGBoost            | 0.7979 | 0.6546 |
# |                  | NaiveBayes         | 0.7649 | 0.4640 |
# |                  | KNN                | 0.7720 | 0.5769 |
# |                  | LightGBM           | 0.1923 | 0.0142 |
# |                  | DecisionTree       | 0.6963 | 0.4503 |
#
# 2. 딥러닝과 머신런닝의 차이 비교하기
# - 벡터화 방법을 바꿔보며(DTM, W2V) 머신러닝 모델1개(성능 잘나온 친구) , 딥러닝 모델 2개(Dense, RNN)를 비교해보세요 평가지표 = accuacry, f1-score
#
# ### 📊 벡터화 방법별 ML/DL 모델 성능 비교 (Accuracy / F1-score)
#
# | Vectorization | Model           | Accuracy | F1-Score |
# |---------------|------------------|----------|----------|
# | Word2Vec      | ML Model (ex. XGBoost) | 0.7244 | 0.7062         |
# |               | Dense NN         | 0.6785         | 0.6607          |
# |               | RNN              | 0.7235         |  0.6893         |

# %%
#!pip install gensim

# %%
#!pip install tensorflow

# %%
from tensorflow.keras.datasets import reuters
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

# %% [markdown]
# # 데이터 준비
# ## index -> text
# ## DTM , TF-idf 학습데이터 준비
# ## W2V 학습데이터 준비

# %%
# 이부분에있는 num_words를 5000과 다른방법으로 바꿔보세요~

(x_train, y_train), (x_test, y_test) = reuters.load_data(num_words=5000, test_split=0.2)

# %%
word_index = reuters.get_word_index(path="reuters_word_index.json")

# %%
index_to_word = { index+3 : word for word, index in word_index.items() }
for index, token in enumerate(("<pad>", "<sos>", "<unk>")):
  index_to_word[index]=token

# %%
decoded = []
for i in range(len(x_train)):
    t = ' '.join([index_to_word[index] for index in x_train[i]])
    decoded.append(t)

x_train = decoded
print(len(x_train))
# Out:
# 8982

# %%
decoded_test = []
for i in range(len(x_test)):
    t = ' '.join([index_to_word[index] for index in x_test[i]])
    decoded_test.append(t)

x_test = decoded_test
print(len(x_test))
# Out:
# 2246

# %%
# 벡터화 DTM, TF-idf 방법
dtmvector = CountVectorizer()

tfidf_transformer = TfidfTransformer()

x_train_dtm = dtmvector.fit_transform(x_train)
x_test_dtm= dtmvector.transform(x_test)

x_train_tfidf = tfidf_transformer.fit_transform(x_train_dtm)
x_test_tfidf = tfidf_transformer.transform(x_test_dtm)

# %%
x_train_tfidf.shape
# Out:
# (8982, 4867)

# %%
x_test_tfidf.shape
# Out:
# (2246, 4867)

# %%
x_train[3]
# Out:
# "<sos> the farmers home administration the u s agriculture department's farm lending arm could lose about seven billion dlrs in outstanding principal on its severely <unk> borrowers or about one fourth of its farm loan portfolio the general accounting office gao said in remarks prepared for delivery to the senate agriculture committee brian <unk> senior associate director of gao also said that a preliminary analysis of proposed changes in <unk> financial <unk> standards indicated as many as one half of <unk> borrowers who received new loans from the agency in 1986 would be <unk> under the proposed system the agency has proposed <unk> <unk> credit using a variety of financial <unk> instead of <unk> <unk> on <unk> ability senate agriculture committee chairman <unk> <unk> d <unk> <unk> the proposed <unk> changes telling <unk> administrator <unk> clark at a hearing that they would mark a dramatic shift in the <unk> purpose away from being <unk> <unk> of last <unk> toward becoming a big c
# ...

# %%
# 벡터화 W2V방법
from gensim.models import Word2Vec

# 우선 문장을 토큰화 시킵시다 띄어쓰기 기반으로 해볼게요! -> # 위에서 DTM만들때는 왜 안해줬냐! -> CountVectorizer에서 띄어쓰기 기반 토큰화가 내장되있음
x_train_tokenized = [sentence.split() for sentence in x_train]
x_test_tokenized = [sentence.split() for sentence in x_test]

# vector사이즈를 늘리거나 줄여보세요 아마 512 가장많이쓰이는 방식
model = Word2Vec(sentences = x_train_tokenized, vector_size = 256, window = 5, min_count = 5, workers = 4, sg = 0)
print("모델 학습 완료!")
# Out:
# 모델 학습 완료!

# %%
# W2V이 잘되었는지 확인 -> 여차저차 되긴한것같다
model_result = model.wv.most_similar('man')
print(model_result)
# Out:
# [('distributors', 0.8110975623130798), ('ontario', 0.8041673302650452), ('shelf', 0.8009929656982422), ('gordon', 0.7967568039894104), ('farms', 0.7914966940879822), ('popular', 0.7897852063179016), ('site', 0.7775502800941467), ('canal', 0.7771246433258057), ('peking', 0.7756898999214172), ('iowa', 0.7754939794540405)]

# %%
# 학습된 Word2Vec 모델
w2v_model = model

# 각 문장을 벡터화 시키는 코드
def vectorize_sentence(sentence, model, max_len):
    vecs = []
    for word in sentence:
        if word in model.wv:
            vecs.append(model.wv[word])
        else:
            vecs.append(np.zeros(model.vector_size))
    # Padding
    if len(vecs) < max_len:
        vecs += [np.zeros(model.vector_size)] * (max_len - len(vecs))
    else:
        vecs = vecs[:max_len]
    return np.array(vecs)


# 최대 문장길이를 잘 잡아주세요
x_train_w2v = np.array([vectorize_sentence(s, w2v_model, max_len=100) for s in x_train_tokenized])
x_test_w2v = np.array([vectorize_sentence(s, w2v_model, max_len=100) for s in x_test_tokenized])

# %%
x_train_w2v.shape
# Out:
# (8982, 100, 256)

# %%
x_test_w2v.shape
# Out:
# (2246, 100, 256)

# %% [markdown]
# # 8개 ML모델

# %%
#!pip install xgboost

# %%
# !pip install lightgbm

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.naive_bayes import ComplementNB
from sklearn.neighbors import KNeighborsClassifier
from lightgbm import LGBMClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, f1_score
import pandas as pd

# %%
# Define and train the Logistic Regression model
lr_model = LogisticRegression()
lr_model.fit(x_train_tfidf, y_train)
# Out:
# LogisticRegression()

# %%
# Predict on the test set
y_pred_lr = lr_model.predict(x_test_tfidf)

# Evaluate the model
acc_lr = accuracy_score(y_test, y_pred_lr)
f1_lr = f1_score(y_test, y_pred_lr, average='macro')

print(f"Logistic Regression Accuracy: {acc_lr:.4f}")
print(f"Logistic Regression F1-score: {f1_lr:.4f}")
# Out:
# Logistic Regression Accuracy: 0.7979
# Logistic Regression F1-score: 0.4814

# %%
# Define and train the Linear SVC model
svm_model = LinearSVC()
svm_model.fit(x_train_tfidf, y_train)
# Out:
# LinearSVC()

# %%
# Predict on the test set
y_pred_svm = svm_model.predict(x_test_tfidf)

# Evaluate the model
acc_svm = accuracy_score(y_test, y_pred_svm)
f1_svm = f1_score(y_test, y_pred_svm, average='macro')

print(f"Linear SVC Accuracy: {acc_svm:.4f}")
print(f"Linear SVC F1-score: {f1_svm:.4f}")
# Out:
# Linear SVC Accuracy: 0.8290
# Linear SVC F1-score: 0.6814

# %%
# Define and train the RandomForestClassifier model
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(x_train_tfidf, y_train)

# Predict on the test set
y_pred_rf = rf_model.predict(x_test_tfidf)

# Evaluate the model
acc_rf = accuracy_score(y_test, y_pred_rf)
f1_rf = f1_score(y_test, y_pred_rf, average='macro')

print(f"Random Forest Accuracy: {acc_rf:.4f}")
print(f"Random Forest F1-score: {f1_rf:.4f}")
# Out:
# Random Forest Accuracy: 0.7685
# Random Forest F1-score: 0.4463

# %%
# Define and train the XGBoost model
xgb_model = XGBClassifier(n_estimators=100, random_state=42, eval_metric='mlogloss', use_label_encoder=False, n_jobs=-1)
xgb_model.fit(x_train_tfidf, y_train)

# Predict on the test set
y_pred_xgb = xgb_model.predict(x_test_tfidf)

# Evaluate the model
acc_xgb = accuracy_score(y_test, y_pred_xgb)
f1_xgb = f1_score(y_test, y_pred_xgb, average='macro')

print(f"XGBoost Accuracy: {acc_xgb:.4f}")
print(f"XGBoost F1-score: {f1_xgb:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:183: UserWarning: [04:21:42] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBoost Accuracy: 0.7996
# XGBoost F1-score: 0.6540

# %%
# Define and train the Complement Naive Bayes model
cnb_model = ComplementNB()
cnb_model.fit(x_train_tfidf, y_train)
# Out:
# ComplementNB()

# %%
# Predict on the test set
y_pred_cnb = cnb_model.predict(x_test_tfidf)

# Evaluate the model
acc_cnb = accuracy_score(y_test, y_pred_cnb)
f1_cnb = f1_score(y_test, y_pred_cnb, average='macro')

print(f"Complement Naive Bayes Accuracy: {acc_cnb:.4f}")
print(f"Complement Naive Bayes F1-score: {f1_cnb:.4f}")
# Out:
# Complement Naive Bayes Accuracy: 0.7707
# Complement Naive Bayes F1-score: 0.4820

# %%
# Define and train the KNN model
knn_model = KNeighborsClassifier(n_neighbors=5) # You can adjust n_neighbors
knn_model.fit(x_train_tfidf, y_train)

# Predict on the test set
y_pred_knn = knn_model.predict(x_test_tfidf)

# Evaluate the model
acc_knn = accuracy_score(y_test, y_pred_knn)
f1_knn = f1_score(y_test, y_pred_knn, average='macro')

print(f"KNN Accuracy: {acc_knn:.4f}")
print(f"KNN F1-score: {f1_knn:.4f}")
# Out:
# KNN Accuracy: 0.7823
# KNN F1-score: 0.5819

# %%
# Define and train the LightGBM model
lgbm_model = LGBMClassifier(random_state=42, n_jobs=-1)
lgbm_model.fit(x_train_tfidf, y_train)

# Predict on the test set
y_pred_lgbm = lgbm_model.predict(x_test_tfidf)

# Evaluate the model
acc_lgbm = accuracy_score(y_test, y_pred_lgbm)
f1_lgbm = f1_score(y_test, y_pred_lgbm, average='macro')

print(f"LightGBM Accuracy: {acc_lgbm:.4f}")
print(f"LightGBM F1-score: {f1_lgbm:.4f}")
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.094787 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 163231
# [LightGBM] [Info] Number of data points in the train set: 8982, number of used features: 3957
# [LightGBM] [Info] Start training from score -5.095645
# [LightGBM] [Info] Start training from score -3.034552
# [LightGBM] [Info] Start training from score -4.798913
# [LightGBM] [Info] Start training from score -1.044967
# [LightGBM] [Info] Start training from score -1.527906
# [LightGBM] [Info] Start training from score -6.269765
# [LightGBM] [Info] Start training from score -5.231777
# [LightGBM] [Info] Start training from score -6.330389
# [LightGBM] [Info] Start training from score -4.168504
# [LightGBM] [Info] Start training from score -4.487857
# [LightGBM] [Info] Start training from score -4.282696
# ...

# %%
# Define and train the Decision Tree model
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(x_train_tfidf, y_train)

# Predict on the test set
y_pred_dt = dt_model.predict(x_test_tfidf)

# Evaluate the model
acc_dt = accuracy_score(y_test, y_pred_dt)
f1_dt = f1_score(y_test, y_pred_dt, average='macro')

print(f"Decision Tree Accuracy: {acc_dt:.4f}")
print(f"Decision Tree F1-score: {f1_dt:.4f}")
# Out:
# Decision Tree Accuracy: 0.6995
# Decision Tree F1-score: 0.4480

# %%
# Create a dictionary with model names and their scores
results = {
    'Model': ['Logistic Regression', 'SVM', 'Random Forest', 'XGBoost', 'Complement Naive Bayes', 'KNN', 'LightGBM', 'Decision Tree'],
    'Accuracy': [acc_lr, acc_svm, acc_rf, acc_xgb, acc_cnb, acc_knn, acc_lgbm, acc_dt],
    'F1-Score': [f1_lr, f1_svm, f1_rf, f1_xgb, f1_cnb, f1_knn, f1_lgbm, f1_dt]
}

# Create a pandas DataFrame from the dictionary
results_df = pd.DataFrame(results)

# Display the DataFrame
display(results_df)
# Out:
#                     Model  Accuracy  F1-Score
# 0     Logistic Regression  0.797863  0.481380
# 1                     SVM  0.829029  0.681414
# 2           Random Forest  0.768477  0.446252
# 3                 XGBoost  0.799644  0.653952
# 4  Complement Naive Bayes  0.770703  0.482035
# 5                     KNN  0.782280  0.581912
# 6                LightGBM  0.349065  0.011250
# 7           Decision Tree  0.699466  0.448043

# %% [markdown]
# # Word2Vec 변환후 XGBoost

# %%
# 데이터를 단어단위에서 문장단위로 바꿔줘야합니다.. ML은 2차원데이터만 받을수있기때문
# 문장에 대해서 토큰들의 벡터를 평균을 취해줍니다.

# Word2Vec 임베딩 시퀀스: (8982, 100, 256)
x_w2v_seq_train = x_train_w2v
x_w2v_seq_test = x_test_w2v
# 평균 풀링 → (8982, 256)
x_w2v_avg_train = np.mean(x_w2v_seq_train, axis=1)
x_w2v_avg_test = np.mean(x_w2v_seq_test, axis=1)
print(x_w2v_avg_train.shape)  # (8982, 256)
# Out:
# (8982, 256)

# %%
# Word2Vec 데이터로 XGBoost 모델 학습하기
from xgboost import XGBClassifier


# XGBoost 모델 학습
xgb_model = XGBClassifier(n_estimators=100, max_depth=5, eval_metric='mlogloss', n_jobs=-1)
xgb_model.fit(x_w2v_avg_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=-1,
#               num_parallel_tree=None, ...)

# %%
# 예측
y_pred = xgb_model.predict(x_w2v_avg_test)

# 평가 지표
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"✅ Accuracy : {acc:.4f}")
print(f"✅ F1-score : {f1:.4f}")
# Out:
# ✅ Accuracy : 0.7244
# ✅ F1-score : 0.7062

# %% [markdown]
# # Dense NN 딥러닝 모델

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, LSTM, Dense, Dropout


dense_model = Sequential([
    Flatten(input_shape=(100, 256)),  # (seq_len, embedding_dim)
    Dense(256, activation='relu'), # 첫 번째 Dense 레이어 유닛 수를 256으로 변경
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(46, activation='softmax')   # 클래스 수에 맞게 조정 46개로 맞춰주세요!
])

dense_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
dense_model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_3 (Flatten)             │ (None, 25600)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 256)            │     6,553,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 256)            │             0 │
# ...

# %%
# 시간이 좀 걸립니다! 한 20분정도..
dense_model.fit(x_train_w2v, y_train, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/10
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 14s 60ms/step - accuracy: 0.5431 - loss: 2.1118 - val_accuracy: 0.6756 - val_loss: 1.4286
# Epoch 2/10
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 59ms/step - accuracy: 0.6895 - loss: 1.2938 - val_accuracy: 0.6806 - val_loss: 1.3930
# Epoch 3/10
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 58ms/step - accuracy: 0.7510 - loss: 1.0614 - val_accuracy: 0.6956 - val_loss: 1.3547
# Epoch 4/10
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 58ms/step - accuracy: 0.7961 - loss: 0.8446 - val_accuracy: 0.6984 - val_loss: 1.3638
# Epoch 5/10
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 60ms/step - accuracy: 0.8119 - loss: 0.7749 - val_accuracy: 0.6962 - val_loss: 1.4432
# Epoch 6/10
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 59ms/step - accuracy: 0.8336 - loss: 0.7037 - val_accuracy: 0.6956 - val_loss: 1.4552
# Epoch 7/10
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 58ms/step - accuracy: 0.8504 - loss: 0.6079 - val_accuracy: 0.6884 - val_loss: 1.4685
# Epoch 8/10
# ...

# %%
y_pred_proba = dense_model.predict(x_test_w2v)
y_pred = np.argmax(y_pred_proba, axis=1)

acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"✅ Accuracy: {acc:.4f}")
print(f"✅ F1-score: {f1:.4f}")
# Out:
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# ✅ Accuracy: 0.6785
# ✅ F1-score: 0.6607

# %% [markdown]
# # RNN 딥러닝 모델

# %%
# rnn 시계열 특징 데이터 특화 모델

rnn_model = Sequential([
    LSTM(128, input_shape=(100, 256)),  # (seq_len, embedding_dim)
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(46, activation='softmax')   # 클래스 수에 맞게 조정 46개로 맞춰주세요~
])

rnn_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
rnn_model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 128)            │       197,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 64)             │         8,256 │
# ...

# %%
# 시간이 좀 걸립니다! 한 20분정도
rnn_model.fit(x_train_w2v, y_train, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/10
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 15s 63ms/step - accuracy: 0.4145 - loss: 2.5971 - val_accuracy: 0.5899 - val_loss: 1.7382
# Epoch 2/10
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 14s 61ms/step - accuracy: 0.5902 - loss: 1.7814 - val_accuracy: 0.6260 - val_loss: 1.5663
# Epoch 3/10
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 14s 61ms/step - accuracy: 0.6403 - loss: 1.5265 - val_accuracy: 0.6500 - val_loss: 1.4465
# Epoch 4/10
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 14s 61ms/step - accuracy: 0.6479 - loss: 1.4457 - val_accuracy: 0.6923 - val_loss: 1.3131
# Epoch 5/10
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 14s 62ms/step - accuracy: 0.6668 - loss: 1.4002 - val_accuracy: 0.6945 - val_loss: 1.3019
# Epoch 6/10
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 14s 61ms/step - accuracy: 0.6910 - loss: 1.2805 - val_accuracy: 0.7129 - val_loss: 1.2371
# Epoch 7/10
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 14s 61ms/step - accuracy: 0.7005 - loss: 1.2055 - val_accuracy: 0.7234 - val_loss: 1.1707
# Epoch 8/10
# ...

# %% [markdown]
# # 로스가 떨어지는 폭을 보아하니 좀더 돌리면 점수가 더 높게 나올것같습니다!
#
# 여기까지 실험하고 시간이 좀 남으시는 분들만 실험해보시길

# %%
y_pred_proba = rnn_model.predict(x_test_w2v)
y_pred = np.argmax(y_pred_proba, axis=1)

acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"✅ Accuracy: {acc:.4f}")
print(f"✅ F1-score: {f1:.4f}")
# Out:
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# ✅ Accuracy: 0.7235
# ✅ F1-score: 0.6893

# %%
# # TF-idf데이터로 XGBoost 모델 학습하기

# # 이친구도 시간좀 걸립니다!

# from xgboost import XGBClassifier

# # XGBoost 모델 학습
# xgb_model = XGBClassifier(n_estimators=100, max_depth=5, eval_metric='mlogloss', n_jobs=-1)
# xgb_model.fit(x_train_tfidf, y_train)

# %%
# # 예측
# y_pred = xgb_model.predict(x_test_tfidf)

# # 평가 지표
# acc = accuracy_score(y_test, y_pred)
# f1 = f1_score(y_test, y_pred, average='macro')

# print(f"✅ Accuracy : {acc:.4f}")
# print(f"✅ F1-score : {f1:.4f}")

# %%
# from sklearn.naive_bayes import MultinomialNB #다항분포 나이브 베이즈 모델
# from sklearn.linear_model import LogisticRegression, SGDClassifier
# from sklearn.naive_bayes import ComplementNB
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.ensemble import GradientBoostingClassifier
# from sklearn.ensemble import VotingClassifier
# from sklearn.svm import LinearSVC
# from sklearn.metrics import accuracy_score #정확도 계산

# %%
# cb = ComplementNB()
# cb.fit(x_train_tfidf, y_train)

# %%
# predicted = cb.predict(x_test_tfidf) #테스트 데이터에 대한 예측
# print("정확도:", accuracy_score(y_test, predicted)) #예측값과 실제값 비교

# f1 = f1_score(y_test, y_pred, average='macro')
# print(f"✅ F1-score : {f1:.4f}")
